# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Basic Neural Network (4 Dense Layers)

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 1.8148 - accuracy: 0.3762 - val_loss: 0.9762 - val_accuracy: 0.4017
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0534 - accuracy: 0.4395 - val_loss: 1.5538 - val_accuracy: 0.3299
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0092 - accuracy: 0.4653 - val_loss: 0.9762 - val_accuracy: 0.3949
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.9488 - accuracy: 0.5123 - val_loss: 0.8726 - val_accuracy: 0.5647
# Epoch 5/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0402 - accuracy: 0.4337 - val_loss: 1.0929 - val_accuracy: 0.3892
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0927 - accuracy: 0.3823 - val_loss: 1.0914 - val_accuracy: 0.3892
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 11/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 12/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 13/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 14/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 15/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 16/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 17/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 18/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 19/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 20/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 21/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 22/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 23/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 24/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 25/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 26/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 27/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 28/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 29/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 30/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 31/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 32/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 33/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 34/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 35/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 36/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 37/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 38/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 39/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 40/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 41/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 42/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 43/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 44/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 45/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 46/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 47/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 48/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 1.0927 - accuracy: 0.3812
# Test Accuracy: 38.1184%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 9, 59, 32)         320
#
#  average_pooling2d_19 (Avera  (None, 4, 29, 32)        0
#  gePooling2D)
#
#  dropout_17 (Dropout)        (None, 4, 29, 32)         0
#
#  conv2d_23 (Conv2D)          (None, 2, 27, 64)         18496
#
#  average_pooling2d_20 (Avera  (None, 1, 13, 64)        0
#  gePooling2D)
#
#  dropout_18 (Dropout)        (None, 1, 13, 64)         0
#
#  flatten_14 (Flatten)        (None, 832)               0
#
#  dense_57 (Dense)            (None, 64)                53312
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_58 (Dense)            (None, 64)                4160
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_59 (Dense)            (None, 64)                4160
#
#  dense_60 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 80,643
# Trainable params: 80,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=64)
# Out:
# Epoch 1/50
# 175/175 [==============================] - 3s 14ms/step - loss: 1.2556 - accuracy: 0.3568 - val_loss: 1.0940 - val_accuracy: 0.3892
# Epoch 2/50
# 175/175 [==============================] - 2s 12ms/step - loss: 1.0957 - accuracy: 0.3727 - val_loss: 1.0932 - val_accuracy: 0.3892
# Epoch 3/50
# 175/175 [==============================] - 2s 14ms/step - loss: 1.0921 - accuracy: 0.3766 - val_loss: 1.0916 - val_accuracy: 0.3892
# Epoch 4/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.9726 - accuracy: 0.4824 - val_loss: 0.8210 - val_accuracy: 0.5822
# Epoch 5/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.6928 - accuracy: 0.6778 - val_loss: 0.5211 - val_accuracy: 0.7820
# Epoch 6/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4861 - accuracy: 0.7952 - val_loss: 0.3386 - val_accuracy: 0.8746
# Epoch 7/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3913 - accuracy: 0.8428 - val_loss: 0.2746 - val_accuracy: 0.8946
# Epoch 8/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3572 - accuracy: 0.8614 - val_loss: 0.2482 - val_accuracy: 0.9096
# Epoch 9/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3286 - accuracy: 0.8685 - val_loss: 0.2293 - val_accuracy: 0.9196
# Epoch 10/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3096 - accuracy: 0.8759 - val_loss: 0.2719 - val_accuracy: 0.8885
# Epoch 11/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2944 - accuracy: 0.8792 - val_loss: 0.2644 - val_accuracy: 0.8931
# Epoch 12/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2938 - accuracy: 0.8811 - val_loss: 0.2177 - val_accuracy: 0.9192
# Epoch 13/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2793 - accuracy: 0.8877 - val_loss: 0.1940 - val_accuracy: 0.9264
# Epoch 14/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2662 - accuracy: 0.8943 - val_loss: 0.2263 - val_accuracy: 0.9060
# Epoch 15/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2828 - accuracy: 0.8858 - val_loss: 0.2022 - val_accuracy: 0.9249
# Epoch 16/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2552 - accuracy: 0.8954 - val_loss: 0.1852 - val_accuracy: 0.9307
# Epoch 17/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2501 - accuracy: 0.8966 - val_loss: 0.1878 - val_accuracy: 0.9235
# Epoch 18/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2486 - accuracy: 0.9019 - val_loss: 0.1869 - val_accuracy: 0.9307
# Epoch 19/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2475 - accuracy: 0.8962 - val_loss: 0.1975 - val_accuracy: 0.9289
# Epoch 20/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2444 - accuracy: 0.8987 - val_loss: 0.1855 - val_accuracy: 0.9303
# Epoch 21/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2489 - accuracy: 0.8994 - val_loss: 0.1780 - val_accuracy: 0.9325
# Epoch 22/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2540 - accuracy: 0.8929 - val_loss: 0.1922 - val_accuracy: 0.9242
# Epoch 23/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2350 - accuracy: 0.9051 - val_loss: 0.1713 - val_accuracy: 0.9307
# Epoch 24/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2404 - accuracy: 0.9029 - val_loss: 0.1868 - val_accuracy: 0.9314
# Epoch 25/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2275 - accuracy: 0.9055 - val_loss: 0.1755 - val_accuracy: 0.9346
# Epoch 26/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2329 - accuracy: 0.9061 - val_loss: 0.2027 - val_accuracy: 0.9235
# Epoch 27/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2327 - accuracy: 0.9038 - val_loss: 0.1850 - val_accuracy: 0.9292
# Epoch 28/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2277 - accuracy: 0.9087 - val_loss: 0.1841 - val_accuracy: 0.9321
# Epoch 29/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2329 - accuracy: 0.9038 - val_loss: 0.1772 - val_accuracy: 0.9282
# Epoch 30/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2247 - accuracy: 0.9108 - val_loss: 0.2090 - val_accuracy: 0.9192
# Epoch 31/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2173 - accuracy: 0.9120 - val_loss: 0.1599 - val_accuracy: 0.9371
# Epoch 32/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2181 - accuracy: 0.9131 - val_loss: 0.1709 - val_accuracy: 0.9303
# Epoch 33/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2115 - accuracy: 0.9165 - val_loss: 0.1694 - val_accuracy: 0.9385
# Epoch 34/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2116 - accuracy: 0.9145 - val_loss: 0.1731 - val_accuracy: 0.9335
# Epoch 35/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2210 - accuracy: 0.9127 - val_loss: 0.1640 - val_accuracy: 0.9378
# Epoch 36/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2119 - accuracy: 0.9154 - val_loss: 0.1682 - val_accuracy: 0.9389
# Epoch 37/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2018 - accuracy: 0.9200 - val_loss: 0.1559 - val_accuracy: 0.9425
# Epoch 38/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2118 - accuracy: 0.9151 - val_loss: 0.1706 - val_accuracy: 0.9342
# Epoch 39/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2046 - accuracy: 0.9206 - val_loss: 0.1678 - val_accuracy: 0.9403
# Epoch 40/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2073 - accuracy: 0.9145 - val_loss: 0.1638 - val_accuracy: 0.9414
# Epoch 41/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2013 - accuracy: 0.9213 - val_loss: 0.1652 - val_accuracy: 0.9375
# Epoch 42/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2085 - accuracy: 0.9148 - val_loss: 0.1675 - val_accuracy: 0.9321
# Epoch 43/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2004 - accuracy: 0.9234 - val_loss: 0.1668 - val_accuracy: 0.9335
# Epoch 44/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2022 - accuracy: 0.9197 - val_loss: 0.1609 - val_accuracy: 0.9350
# Epoch 45/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2038 - accuracy: 0.9189 - val_loss: 0.1590 - val_accuracy: 0.9389
# Epoch 46/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1930 - accuracy: 0.9247 - val_loss: 0.1614 - val_accuracy: 0.9375
# Epoch 47/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2012 - accuracy: 0.9206 - val_loss: 0.1626 - val_accuracy: 0.9414
# Epoch 48/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.1943 - accuracy: 0.9224 - val_loss: 0.1672 - val_accuracy: 0.9403
# Epoch 49/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1936 - accuracy: 0.9228 - val_loss: 0.1707 - val_accuracy: 0.9357
# Epoch 50/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2037 - accuracy: 0.9187 - val_loss: 0.1713 - val_accuracy: 0.9310

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 0.1608 - accuracy: 0.9345
# Test Accuracy: 93.4515%
