# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Basic Neural Network (4 Dense Layers)

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 1.8148 - accuracy: 0.3762 - val_loss: 0.9762 - val_accuracy: 0.4017
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0534 - accuracy: 0.4395 - val_loss: 1.5538 - val_accuracy: 0.3299
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0092 - accuracy: 0.4653 - val_loss: 0.9762 - val_accuracy: 0.3949
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.9488 - accuracy: 0.5123 - val_loss: 0.8726 - val_accuracy: 0.5647
# Epoch 5/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0402 - accuracy: 0.4337 - val_loss: 1.0929 - val_accuracy: 0.3892
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0927 - accuracy: 0.3823 - val_loss: 1.0914 - val_accuracy: 0.3892
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 11/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 12/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 13/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 14/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 15/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 16/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 17/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 18/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 19/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 20/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 21/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 22/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 23/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 24/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 25/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 26/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 27/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 28/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 29/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 30/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 31/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 32/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 33/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 34/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 35/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 36/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 37/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 38/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 39/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 40/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 41/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 42/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 43/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 44/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 45/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 46/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 47/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 48/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 1.0927 - accuracy: 0.3812
# Test Accuracy: 38.1184%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (25)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (25)
# ### Dense Layer (64)
# ### Dense Layer (64)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 9, 59, 32)         320
#
#  average_pooling2d_9 (Averag  (None, 4, 29, 32)        0
#  ePooling2D)
#
#  dropout_2 (Dropout)         (None, 4, 29, 32)         0
#
#  conv2d_13 (Conv2D)          (None, 2, 27, 64)         18496
#
#  average_pooling2d_10 (Avera  (None, 1, 13, 64)        0
#  gePooling2D)
#
#  dropout_3 (Dropout)         (None, 1, 13, 64)         0
#
#  flatten_9 (Flatten)         (None, 832)               0
#
#  dense_37 (Dense)            (None, 64)                53312
#
#  dense_38 (Dense)            (None, 64)                4160
#
#  dense_39 (Dense)            (None, 64)                4160
#
#  dense_40 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 80,643
# Trainable params: 80,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=64)
# Out:
# Epoch 1/50
# 175/175 [==============================] - 6s 15ms/step - loss: 1.3325 - accuracy: 0.3614 - val_loss: 1.0893 - val_accuracy: 0.3892
# Epoch 2/50
# 175/175 [==============================] - 2s 11ms/step - loss: 1.0891 - accuracy: 0.3910 - val_loss: 1.0824 - val_accuracy: 0.3174
# Epoch 3/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.8854 - accuracy: 0.5451 - val_loss: 0.6372 - val_accuracy: 0.7448
# Epoch 4/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4868 - accuracy: 0.7908 - val_loss: 0.3524 - val_accuracy: 0.8706
# Epoch 5/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4210 - accuracy: 0.8256 - val_loss: 0.3113 - val_accuracy: 0.8799
# Epoch 6/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3629 - accuracy: 0.8528 - val_loss: 0.2649 - val_accuracy: 0.9024
# Epoch 7/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3282 - accuracy: 0.8651 - val_loss: 0.2456 - val_accuracy: 0.9081
# Epoch 8/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3090 - accuracy: 0.8741 - val_loss: 0.2531 - val_accuracy: 0.9149
# Epoch 9/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2995 - accuracy: 0.8761 - val_loss: 0.2198 - val_accuracy: 0.9085
# Epoch 10/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2850 - accuracy: 0.8832 - val_loss: 0.2199 - val_accuracy: 0.9167
# Epoch 11/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2802 - accuracy: 0.8811 - val_loss: 0.2206 - val_accuracy: 0.9160
# Epoch 12/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2603 - accuracy: 0.8925 - val_loss: 0.2102 - val_accuracy: 0.9221
# Epoch 13/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2525 - accuracy: 0.8937 - val_loss: 0.1886 - val_accuracy: 0.9267
# Epoch 14/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2463 - accuracy: 0.8981 - val_loss: 0.2086 - val_accuracy: 0.9160
# Epoch 15/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2415 - accuracy: 0.9004 - val_loss: 0.1864 - val_accuracy: 0.9292
# Epoch 16/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2313 - accuracy: 0.9032 - val_loss: 0.1833 - val_accuracy: 0.9314
# Epoch 17/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2288 - accuracy: 0.9040 - val_loss: 0.1800 - val_accuracy: 0.9332
# Epoch 18/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2268 - accuracy: 0.9069 - val_loss: 0.1853 - val_accuracy: 0.9321
# Epoch 19/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2317 - accuracy: 0.9046 - val_loss: 0.1730 - val_accuracy: 0.9339
# Epoch 20/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2173 - accuracy: 0.9112 - val_loss: 0.1936 - val_accuracy: 0.9289
# Epoch 21/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2145 - accuracy: 0.9117 - val_loss: 0.1695 - val_accuracy: 0.9307
# Epoch 22/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2182 - accuracy: 0.9099 - val_loss: 0.1716 - val_accuracy: 0.9364
# Epoch 23/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2197 - accuracy: 0.9097 - val_loss: 0.1697 - val_accuracy: 0.9360
# Epoch 24/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2170 - accuracy: 0.9112 - val_loss: 0.1832 - val_accuracy: 0.9310
# Epoch 25/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2086 - accuracy: 0.9164 - val_loss: 0.1724 - val_accuracy: 0.9360
# Epoch 26/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2085 - accuracy: 0.9137 - val_loss: 0.1870 - val_accuracy: 0.9299
# Epoch 27/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2088 - accuracy: 0.9155 - val_loss: 0.1610 - val_accuracy: 0.9421
# Epoch 28/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1938 - accuracy: 0.9212 - val_loss: 0.1612 - val_accuracy: 0.9389
# Epoch 29/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1988 - accuracy: 0.9184 - val_loss: 0.1603 - val_accuracy: 0.9400
# Epoch 30/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1999 - accuracy: 0.9185 - val_loss: 0.1719 - val_accuracy: 0.9353
# Epoch 31/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1963 - accuracy: 0.9207 - val_loss: 0.1674 - val_accuracy: 0.9350
# Epoch 32/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1959 - accuracy: 0.9194 - val_loss: 0.1663 - val_accuracy: 0.9382
# Epoch 33/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1898 - accuracy: 0.9236 - val_loss: 0.1720 - val_accuracy: 0.9299
# Epoch 34/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1897 - accuracy: 0.9226 - val_loss: 0.1703 - val_accuracy: 0.9364
# Epoch 35/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2036 - accuracy: 0.9145 - val_loss: 0.1815 - val_accuracy: 0.9325
# Epoch 36/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.1914 - accuracy: 0.9239 - val_loss: 0.1586 - val_accuracy: 0.9403
# Epoch 37/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1904 - accuracy: 0.9238 - val_loss: 0.1651 - val_accuracy: 0.9382
# Epoch 38/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1848 - accuracy: 0.9231 - val_loss: 0.1776 - val_accuracy: 0.9317
# Epoch 39/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1863 - accuracy: 0.9243 - val_loss: 0.1696 - val_accuracy: 0.9314
# Epoch 40/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1911 - accuracy: 0.9207 - val_loss: 0.1759 - val_accuracy: 0.9342
# Epoch 41/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1920 - accuracy: 0.9218 - val_loss: 0.1729 - val_accuracy: 0.9371
# Epoch 42/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1846 - accuracy: 0.9243 - val_loss: 0.1788 - val_accuracy: 0.9271
# Epoch 43/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1876 - accuracy: 0.9243 - val_loss: 0.1715 - val_accuracy: 0.9332
# Epoch 44/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1867 - accuracy: 0.9265 - val_loss: 0.1725 - val_accuracy: 0.9360
# Epoch 45/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1825 - accuracy: 0.9253 - val_loss: 0.1816 - val_accuracy: 0.9339
# Epoch 46/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1840 - accuracy: 0.9247 - val_loss: 0.1782 - val_accuracy: 0.9317
# Epoch 47/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1867 - accuracy: 0.9239 - val_loss: 0.1687 - val_accuracy: 0.9367
# Epoch 48/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1722 - accuracy: 0.9294 - val_loss: 0.1692 - val_accuracy: 0.9353
# Epoch 49/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1757 - accuracy: 0.9294 - val_loss: 0.1664 - val_accuracy: 0.9378
# Epoch 50/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1768 - accuracy: 0.9288 - val_loss: 0.1704 - val_accuracy: 0.9342

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.1711 - accuracy: 0.9322
# Test Accuracy: 93.2228%
