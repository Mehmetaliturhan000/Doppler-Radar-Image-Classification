# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Basic Neural Network (4 Dense Layers)

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 1.8148 - accuracy: 0.3762 - val_loss: 0.9762 - val_accuracy: 0.4017
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0534 - accuracy: 0.4395 - val_loss: 1.5538 - val_accuracy: 0.3299
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0092 - accuracy: 0.4653 - val_loss: 0.9762 - val_accuracy: 0.3949
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.9488 - accuracy: 0.5123 - val_loss: 0.8726 - val_accuracy: 0.5647
# Epoch 5/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0402 - accuracy: 0.4337 - val_loss: 1.0929 - val_accuracy: 0.3892
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0927 - accuracy: 0.3823 - val_loss: 1.0914 - val_accuracy: 0.3892
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 11/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 12/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 13/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 14/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 15/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 16/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 17/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 18/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 19/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 20/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 21/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 22/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 23/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 24/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 25/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 26/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 27/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 28/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 29/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 30/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 31/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 32/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 33/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 34/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 35/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 36/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 37/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 38/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 39/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 40/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 41/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 42/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 43/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 44/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 45/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 46/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 47/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 48/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 1.0927 - accuracy: 0.3812
# Test Accuracy: 38.1184%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dense Layer (64)
# ### Dense Layer (64)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 9, 59, 32)         320
#
#  average_pooling2d_3 (Averag  (None, 4, 29, 32)        0
#  ePooling2D)
#
#  conv2d_7 (Conv2D)           (None, 2, 27, 64)         18496
#
#  average_pooling2d_4 (Averag  (None, 1, 13, 64)        0
#  ePooling2D)
#
#  flatten_6 (Flatten)         (None, 832)               0
#
#  dense_25 (Dense)            (None, 64)                53312
#
#  dense_26 (Dense)            (None, 64)                4160
#
#  dense_27 (Dense)            (None, 64)                4160
#
#  dense_28 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 80,643
# Trainable params: 80,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=64)
# Out:
# Epoch 1/50
# 175/175 [==============================] - 3s 12ms/step - loss: 1.1352 - accuracy: 0.5154 - val_loss: 0.7483 - val_accuracy: 0.7405
# Epoch 2/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.6203 - accuracy: 0.7405 - val_loss: 0.5494 - val_accuracy: 0.7952
# Epoch 3/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.4712 - accuracy: 0.8125 - val_loss: 0.4354 - val_accuracy: 0.8338
# Epoch 4/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3926 - accuracy: 0.8471 - val_loss: 0.4043 - val_accuracy: 0.8445
# Epoch 5/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3496 - accuracy: 0.8661 - val_loss: 0.3381 - val_accuracy: 0.8695
# Epoch 6/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3297 - accuracy: 0.8698 - val_loss: 0.3311 - val_accuracy: 0.8660
# Epoch 7/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3057 - accuracy: 0.8777 - val_loss: 0.2757 - val_accuracy: 0.8853
# Epoch 8/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.2764 - accuracy: 0.8903 - val_loss: 0.2696 - val_accuracy: 0.8964
# Epoch 9/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2675 - accuracy: 0.8952 - val_loss: 0.2453 - val_accuracy: 0.9074
# Epoch 10/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2547 - accuracy: 0.8976 - val_loss: 0.2686 - val_accuracy: 0.8946
# Epoch 11/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2424 - accuracy: 0.9030 - val_loss: 0.2289 - val_accuracy: 0.9092
# Epoch 12/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2379 - accuracy: 0.9056 - val_loss: 0.2278 - val_accuracy: 0.9160
# Epoch 13/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.2231 - accuracy: 0.9099 - val_loss: 0.2106 - val_accuracy: 0.9207
# Epoch 14/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2215 - accuracy: 0.9108 - val_loss: 0.2033 - val_accuracy: 0.9235
# Epoch 15/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2106 - accuracy: 0.9155 - val_loss: 0.2049 - val_accuracy: 0.9235
# Epoch 16/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.2066 - accuracy: 0.9177 - val_loss: 0.2000 - val_accuracy: 0.9235
# Epoch 17/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2150 - accuracy: 0.9122 - val_loss: 0.2048 - val_accuracy: 0.9224
# Epoch 18/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.2039 - accuracy: 0.9187 - val_loss: 0.2089 - val_accuracy: 0.9196
# Epoch 19/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1941 - accuracy: 0.9231 - val_loss: 0.1987 - val_accuracy: 0.9214
# Epoch 20/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1943 - accuracy: 0.9239 - val_loss: 0.1857 - val_accuracy: 0.9299
# Epoch 21/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1932 - accuracy: 0.9267 - val_loss: 0.1904 - val_accuracy: 0.9271
# Epoch 22/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1955 - accuracy: 0.9213 - val_loss: 0.1950 - val_accuracy: 0.9328
# Epoch 23/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1827 - accuracy: 0.9272 - val_loss: 0.1809 - val_accuracy: 0.9335
# Epoch 24/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1783 - accuracy: 0.9312 - val_loss: 0.1823 - val_accuracy: 0.9335
# Epoch 25/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1767 - accuracy: 0.9312 - val_loss: 0.1801 - val_accuracy: 0.9346
# Epoch 26/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1748 - accuracy: 0.9307 - val_loss: 0.2066 - val_accuracy: 0.9260
# Epoch 27/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1691 - accuracy: 0.9338 - val_loss: 0.1646 - val_accuracy: 0.9417
# Epoch 28/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1685 - accuracy: 0.9329 - val_loss: 0.1903 - val_accuracy: 0.9328
# Epoch 29/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1696 - accuracy: 0.9317 - val_loss: 0.1735 - val_accuracy: 0.9342
# Epoch 30/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1632 - accuracy: 0.9368 - val_loss: 0.1834 - val_accuracy: 0.9303
# Epoch 31/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1567 - accuracy: 0.9398 - val_loss: 0.2468 - val_accuracy: 0.8953
# Epoch 32/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1635 - accuracy: 0.9353 - val_loss: 0.1660 - val_accuracy: 0.9392
# Epoch 33/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1492 - accuracy: 0.9418 - val_loss: 0.1685 - val_accuracy: 0.9371
# Epoch 34/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1637 - accuracy: 0.9341 - val_loss: 0.1907 - val_accuracy: 0.9257
# Epoch 35/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1469 - accuracy: 0.9429 - val_loss: 0.1632 - val_accuracy: 0.9392
# Epoch 36/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1536 - accuracy: 0.9390 - val_loss: 0.1751 - val_accuracy: 0.9353
# Epoch 37/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1570 - accuracy: 0.9360 - val_loss: 0.1833 - val_accuracy: 0.9332
# Epoch 38/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1489 - accuracy: 0.9416 - val_loss: 0.1687 - val_accuracy: 0.9367
# Epoch 39/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1490 - accuracy: 0.9412 - val_loss: 0.1815 - val_accuracy: 0.9299
# Epoch 40/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1398 - accuracy: 0.9446 - val_loss: 0.1922 - val_accuracy: 0.9321
# Epoch 41/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1454 - accuracy: 0.9426 - val_loss: 0.1649 - val_accuracy: 0.9407
# Epoch 42/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1381 - accuracy: 0.9441 - val_loss: 0.1926 - val_accuracy: 0.9289
# Epoch 43/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1428 - accuracy: 0.9437 - val_loss: 0.1696 - val_accuracy: 0.9364
# Epoch 44/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1312 - accuracy: 0.9492 - val_loss: 0.1633 - val_accuracy: 0.9417
# Epoch 45/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1273 - accuracy: 0.9496 - val_loss: 0.1717 - val_accuracy: 0.9385
# Epoch 46/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1378 - accuracy: 0.9458 - val_loss: 0.1780 - val_accuracy: 0.9335
# Epoch 47/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1349 - accuracy: 0.9454 - val_loss: 0.1594 - val_accuracy: 0.9417
# Epoch 48/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1239 - accuracy: 0.9509 - val_loss: 0.1648 - val_accuracy: 0.9385
# Epoch 49/50
# 175/175 [==============================] - 2s 9ms/step - loss: 0.1138 - accuracy: 0.9562 - val_loss: 0.1680 - val_accuracy: 0.9371
# Epoch 50/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.1203 - accuracy: 0.9514 - val_loss: 0.1985 - val_accuracy: 0.9328

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.2450 - accuracy: 0.9231
# Test Accuracy: 92.3077%
