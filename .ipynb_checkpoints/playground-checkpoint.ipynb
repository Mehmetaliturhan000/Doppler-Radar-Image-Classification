# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Basic Neural Network (4 Dense Layers)

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 1.0859 - accuracy: 0.3906 - val_loss: 1.0106 - val_accuracy: 0.4035
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.9619 - accuracy: 0.5091 - val_loss: 0.8181 - val_accuracy: 0.6787
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.8127 - accuracy: 0.6183 - val_loss: 0.7702 - val_accuracy: 0.6262
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.6429 - accuracy: 0.7189 - val_loss: 1.0266 - val_accuracy: 0.5211
# Epoch 5/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7785 - val_loss: 0.4057 - val_accuracy: 0.8503
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.4778 - accuracy: 0.8128 - val_loss: 0.4174 - val_accuracy: 0.8420
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.4788 - accuracy: 0.8017 - val_loss: 0.5266 - val_accuracy: 0.7616
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.4305 - accuracy: 0.8297 - val_loss: 0.3502 - val_accuracy: 0.8717
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.4426 - accuracy: 0.8214 - val_loss: 0.4605 - val_accuracy: 0.8138
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.4259 - accuracy: 0.8325 - val_loss: 0.4499 - val_accuracy: 0.8145
# Epoch 11/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.
50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3277 - accuracy: 0.8728 - val_loss: 0.2610 - val_accuracy: 0.9017
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3237 - accuracy: 0.8740 - val_loss: 0.2748 - val_accuracy: 0.8992
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3075 - accuracy: 0.8819 - val_loss: 0.2849 - val_accuracy: 0.8956

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 4s 33ms/step - loss: 0.3985 - accuracy: 0.9194
# Test Accuracy: 91.9359%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Dense Layer (64)
# ### Dense Layer (64)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 9, 59, 32)         320
#
#  flatten_1 (Flatten)         (None, 16992)             0
#
#  dense_5 (Dense)             (None, 64)                1087552
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,096,387
# Trainable params: 1,096,387
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.6387 - accuracy: 0.7176 - val_loss: 0.3777 - val_accuracy: 0.8610
# Epoch 2/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.3276 - accuracy: 0.8722 - val_loss: 0.2867 - val_accuracy: 0.8867
# Epoch 3/50
# 350/350 [==============================] - 16s 45ms/step - loss: 0.2990 - accuracy: 0.8913 - val_loss: 0.2733 - val_accuracy: 0.8931
# Epoch 4/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.2705 - accuracy: 0.9017 - val_loss: 0.2889 - val_accuracy: 0.8821
# Epoch 5/50
# 350/350 [==============================] - 14s 41ms/step - loss: 0.2426 - accuracy: 0.9117 - val_loss: 0.2786 - val_accuracy: 0.8835
# Epoch 6/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2199 - accuracy: 0.9188 - val_loss: 0.2556 - val_accuracy: 0.9021
# Epoch 7/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1937 - accuracy: 0.9289 - val_loss: 0.2045 - val_accuracy: 0.9196
# Epoch 8/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1943 - accuracy: 0.9256 - val_loss: 0.2106 - val_accuracy: 0.9185
# Epoch 9/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1804 - accuracy: 0.9323 - val_loss: 0.2157 - val_accuracy: 0.9146
# Epoch 10/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1633 - accuracy: 0.9370 - val_loss: 0.2148 - val_accuracy: 0.9207
# Epoch 11/50
# 350/350 [==============================] - 14s 41ms/step - loss: 0.1483 - accuracy: 0.9439 - val_loss: 0.2094 - val_accuracy: 0.9199
# Epoch 12/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1374 - accuracy: 0.9506 - val_loss: 0.2139 - val_accuracy: 0.9210
# Epoch 13/50
# 350/350 [==============================] - 15s 44ms/step - loss: 0.1354 - accuracy: 0.9476 - val_loss: 0.2324 - val_accuracy: 0.9178
# Epoch 14/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0
50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.4372 - val_accuracy: 0.9182
# Epoch 46/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.4165 - val_accuracy: 0.9203
# Epoch 47/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0396 - accuracy: 0.9864 - val_loss: 0.3938 - val_accuracy: 0.9060
# Epoch 48/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 0.5662 - val_accuracy: 0.9003
# Epoch 49/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.4320 - val_accuracy: 0.9192
# Epoch 50/50
# 350/350 [==============================] - 15s 43ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.3945 - val_accuracy: 0.9199

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 4s 35ms/step - loss: 0.3985 - accuracy: 0.9194
# Test Accuracy: 91.9359%

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Dense Layer (64)
# ### Dense Layer (32)
# ### Dense Layer (16)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dense(32, activation = 'relu'),
        Dense(16, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 9, 59, 32)         320
#
#  flatten_3 (Flatten)         (None, 16992)             0
#
#  dense_13 (Dense)            (None, 64)                1087552
#
#  dense_14 (Dense)            (None, 32)                2080
#
#  dense_15 (Dense)            (None, 16)                528
#
#  dense_16 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 1,090,531
# Trainable params: 1,090,531
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.7529 - accuracy: 0.6516 - val_loss: 0.3992 - val_accuracy: 0.8620
# Epoch 2/50
# 350/350 [==============================] - 15s 43ms/step - loss: 0.3826 - accuracy: 0.8563 - val_loss: 0.3252 - val_accuracy: 0.8763
# Epoch 3/50
# 350/350 [==============================] - 16s 45ms/step - loss: 0.3145 - accuracy: 0.8851 - val_loss: 0.2952 - val_accuracy: 0.8849
# Epoch 4/50
# 350/350 [==============================] - 16s 44ms/step - loss: 0.2893 - accuracy: 0.8911 - val_loss: 0.3572 - val_accuracy: 0.8588
# Epoch 5/50
# 350/350 [==============================] - 16s 44ms/step - loss: 0.2806 - accuracy: 0.8933 - val_loss: 0.2679 - val_accuracy: 0.9010
# Epoch 6/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2714 - accuracy: 0.8993 - val_loss: 0.2753 - val_accuracy: 0.8981
# Epoch 7/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2485 - accuracy: 0.9061 - val_loss: 0.2604 - val_accuracy: 0.9014
# Epoch 8/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2319 - accuracy: 0.9138 - val_loss: 0.2547 - val_accuracy: 0.9014
# Epoch 9/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.2350 - accuracy: 0.9131 - val_loss: 0.2678 - val_accuracy: 0.8878
# Epoch 10/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.2109 - accuracy: 0.9230 - val_loss: 0.2130 - val_accuracy: 0.9135
# Epoch 11/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1945 - accuracy: 0.9274 - val_loss: 0.2548 - val_accuracy: 0.9017
# Epoch 12/50
# 350/350 [==============================] - 15s 43ms/step - loss: 0.1883 - accuracy: 0.9278 - val_loss: 0.2003 - val_accuracy: 0.9192
# Epoch 13/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1876 - accuracy: 0.9281 - val_loss: 0.2135 - val_accuracy: 0.9178
# Epoch 14/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1726 - accuracy: 0.9342 - val_loss: 0.2272 - val_accuracy: 0.9121
# Epoch 15/50
# 350/350 [==============================] - 14s 40ms/step - loss: 0.1638 - accuracy: 0.9362 - val_loss: 0.2076 - val_accuracy: 0.9189
# Epoch 16/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1572 - accuracy: 0.9394 - val_loss: 0.1991 - val_accuracy: 0.9167
# Epoch 17/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1477 - accuracy: 0.9416 - val_loss: 0.2080 - val_accuracy: 0.9232
# Epoch 18/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.1456 - accuracy: 0.9448 - val_loss: 0.1957 - val_accuracy: 0.9242
# Epoch 19/50
# 350/350 [==============================] - 15s 43ms/step - loss: 0.1334 - accuracy: 0.9494 - val_loss: 0.2027 - val_accuracy: 0.9239
# Epoch 20/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1317 - accuracy: 0.9505 - val_loss: 0.2120 - val_accuracy: 0.9164
# Epoch 21/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1211 - accuracy: 0.9534 - val_loss: 0.1909 - val_accuracy: 0.9246
# Epoch 22/50
# 350/350 [==============================] - 16s 45ms/step - loss: 0.1153 - accuracy: 0.9565 - val_loss: 0.2209 - val_accuracy: 0.9128
# Epoch 23/50
# 350/350 [==============================] - 15s 42ms/step - loss: 0.1043 - accuracy: 0.9611 - val_loss: 0.2348 - val_accuracy: 0.9214
# Epoch 24/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1103 - accuracy: 0.9582 - val_loss: 0.1869 - val_accuracy: 0.9299
# Epoch 25/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0954 - accuracy: 0.9647 - val_loss: 0.2132 - val_accuracy: 0.9282
# Epoch 26/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0939 - accuracy: 0.9648 - val_loss: 0.2132 - val_accuracy: 0.9214
# Epoch 27/50
# 350/350 [==============================] - 19s 54ms/step - loss: 0.0883 - accuracy: 0.9659 - val_loss: 0.2417 - val_accuracy: 0.9264
# Epoch 28/50
# 350/350 [==============================] - 16s 45ms/step - loss: 0.0807 - accuracy: 0.9715 - val_loss: 0.2579 - val_accuracy: 0.9224
# Epoch 29/50
# 350/350 [==============================] - 15s 44ms/step - loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.2806 - val_accuracy: 0.9189
# Epoch 30/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0665 - accuracy: 0.9748 - val_loss: 0.2610 - val_accuracy: 0.9210
# Epoch 31/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0645 - accuracy: 0.9769 - val_loss: 0.2371 - val_accuracy: 0.9214
# Epoch 32/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0458 - accuracy: 0.9845 - val_loss: 0.2810 - val_accuracy: 0.9153
# Epoch 33/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0511 - accuracy: 0.9819 - val_loss: 0.3416 - val_accuracy: 0.9099
# Epoch 34/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0495 - accuracy: 0.9822 - val_loss: 0.2954 - val_accuracy: 0.9192
# Epoch 35/50
# 350/350 [==============================] - 16s 45ms/step - loss: 0.0320 - accuracy: 0.9903 - val_loss: 0.3418 - val_accuracy: 0.9114
# Epoch 36/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0350 - accuracy: 0.9878 - val_loss: 0.2879 - val_accuracy: 0.9117
# Epoch 37/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0269 - accuracy: 0.9912 - val_loss: 0.3419 - val_accuracy: 0.9182
# Epoch 38/50
# 350/350 [==============================] - 15s 44ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 0.3008 - val_accuracy: 0.9199
# Epoch 39/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0136 - accuracy: 0.9966 - val_loss: 0.3247 - val_accuracy: 0.9167
# Epoch 40/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.3097 - val_accuracy: 0.9167
# Epoch 41/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.3726 - val_accuracy: 0.9167
# Epoch 42/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.3514 - val_accuracy: 0.9189
# Epoch 43/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.4665 - val_accuracy: 0.9117
# Epoch 44/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.4827 - val_accuracy: 0.9121
# Epoch 45/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.4379 - val_accuracy: 0.9121
# Epoch 46/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0350 - accuracy: 0.9891 - val_loss: 0.3510 - val_accuracy: 0.9124
# Epoch 47/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0431 - accuracy: 0.9837 - val_loss: 0.3737 - val_accuracy: 0.9089
# Epoch 48/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0398 - accuracy: 0.9853 - val_loss: 0.3794 - val_accuracy: 0.9207
# Epoch 49/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.3799 - val_accuracy: 0.9235
# Epoch 50/50
# 350/350 [==============================] - 16s 45ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.4585 - val_accuracy: 0.9228

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 4s 35ms/step - loss: 1.1391 - accuracy: 0.3214
# Test Accuracy: 32.1418%

# %%
#Main Commit
