# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Basic Neural Network (4 Dense Layers)

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 1.8148 - accuracy: 0.3762 - val_loss: 0.9762 - val_accuracy: 0.4017
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0534 - accuracy: 0.4395 - val_loss: 1.5538 - val_accuracy: 0.3299
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0092 - accuracy: 0.4653 - val_loss: 0.9762 - val_accuracy: 0.3949
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.9488 - accuracy: 0.5123 - val_loss: 0.8726 - val_accuracy: 0.5647
# Epoch 5/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0402 - accuracy: 0.4337 - val_loss: 1.0929 - val_accuracy: 0.3892
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0927 - accuracy: 0.3823 - val_loss: 1.0914 - val_accuracy: 0.3892
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 11/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 12/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 13/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 14/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 15/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 16/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 17/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 18/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 19/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 20/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 21/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 22/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 23/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 24/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 25/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 26/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 27/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 28/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 29/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 30/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 31/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 32/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 33/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 34/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 35/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 36/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 37/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 38/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 39/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 40/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 41/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 42/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 43/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 44/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 45/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 46/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 47/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 48/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 1.0927 - accuracy: 0.3812
# Test Accuracy: 38.1184%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (25)
# ### Dense Layer (64)
# ### Dense Layer (64)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 9, 59, 32)         320
#
#  average_pooling2d_7 (Averag  (None, 4, 29, 32)        0
#  ePooling2D)
#
#  conv2d_11 (Conv2D)          (None, 2, 27, 64)         18496
#
#  average_pooling2d_8 (Averag  (None, 1, 13, 64)        0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 13, 64)         0
#
#  flatten_8 (Flatten)         (None, 832)               0
#
#  dense_33 (Dense)            (None, 64)                53312
#
#  dense_34 (Dense)            (None, 64)                4160
#
#  dense_35 (Dense)            (None, 64)                4160
#
#  dense_36 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params:
150
# 175/175 [==============================] - 2s 13ms/step - loss: 0.0925 - accuracy: 0.9651 - val_loss: 0.2058 - val_accuracy: 0.9285
# Epoch 122/150
# 175/175 [==============================] - 2s 14ms/step - loss: 0.0955 - accuracy: 0.9628 - val_loss: 0.2090 - val_accuracy: 0.9321
# Epoch 123/150
# 175/175 [==============================] - 2s 14ms/step - loss: 0.0896 - accuracy: 0.9659 - val_loss: 0.2210 - val_accuracy: 0.9314
# Epoch 124/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0901 - accuracy: 0.9652 - val_loss: 0.2322 - val_accuracy: 0.9332
# Epoch 125/150
# 175/175 [==============================] - 2s 14ms/step - loss: 0.0803 - accuracy: 0.9693 - val_loss: 0.2232 - val_accuracy: 0.9335
# Epoch 126/150
# 175/175 [==============================] - 2s 11ms/step - loss: 0.0852 - accuracy: 0.9662 - val_loss: 0.2054 - val_accuracy: 0.9307
# Epoch 127/150
# 175/175 [==============================] - 3s 16ms/step - loss: 0.0853 - accuracy: 0.9668 - val_loss: 0.2028 - val_accuracy: 0.9317
# Epoch 128/150
# 175/175 [==============================] - 2s 13ms/step - loss: 0.0911 - accuracy: 0.9634 - val_loss: 0.1926 - val_accuracy: 0.9296
# Epoch 129/150
# 175/175 [==============================] - 3s 16ms/step - loss: 0.0872 - accuracy: 0.9656 - val_loss: 0.2278 - val_accuracy: 0.9332
# Epoch 130/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0826 - accuracy: 0.9687 - val_loss: 0.2139 - val_accuracy: 0.9325
# Epoch 131/150
# 175/175 [==============================] - 3s 16ms/step - loss: 0.0865 - accuracy: 0.9647 - val_loss: 0.2342 - val_accuracy: 0.9239
# Epoch 132/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0878 - accuracy: 0.9642 - val_loss: 0.2543 - val_accuracy: 0.9307
# Epoch 133/150
# 175/175 [==============================] - 3s 16ms/step - loss: 0.0829 - accuracy: 0.9660 - val_loss: 0.1966 - val_accuracy: 0.9321
# Epoch 134/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0800 - accuracy: 0.9697 - val_loss: 0.1955 - val_accuracy: 0.9307
# Epoch 135/150
# 175/175 [==============================] - 3s 17ms/step - loss: 0.0864 - accuracy: 0.9689 - val_loss: 0.2367 - val_accuracy: 0.9307
# Epoch 136/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0833 - accuracy: 0.9695 - val_loss: 0.2283 - val_accuracy: 0.9296
# Epoch 137/150
# 175/175 [==============================] - 3s 16ms/step - loss: 0.0913 - accuracy: 0.9646 - val_loss: 0.2307 - val_accuracy: 0.9264
# Epoch 138/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0822 - accuracy: 0.9676 - val_loss: 0.2011 - val_accuracy: 0.9292
# Epoch 139/150
# 175/175 [==============================] - 3s 15ms/step - loss: 0.0827 - accuracy: 0.9668 - val_loss: 0.2502 - val_accuracy: 0.9274
# Epoch 140/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0825 - accuracy: 0.9663 - val_loss: 0.2008 - val_accuracy: 0.9292
# Epoch 141/150
# 175/175 [==============================] - 3s 17ms/step - loss: 0.0841 - accuracy: 0.9669 - val_loss: 0.2431 - val_accuracy: 0.9192
# Epoch 142/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0798 - accuracy: 0.9705 - val_loss: 0.2099 - val_accuracy: 0.9317
# Epoch 143/150
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0749 - accuracy: 0.9713 - val_loss: 0.2523 - val_accuracy: 0.9328
# Epoch 144/150
# 175/175 [==============================] - 2s 11ms/step - loss: 0.0783 - accuracy: 0.9689 - val_loss: 0.2527 - val_accuracy: 0.9285
# Epoch 145/150
# 175/175 [==============================] - 2s 14ms/step - loss: 0.0703 - accuracy: 0.9722 - val_loss: 0.2503 - val_accuracy: 0.9257
# Epoch 146/150
# 175/175 [==============================] - 2s 13ms/step - loss: 0.0853 - accuracy: 0.9658 - val_loss: 0.2477 - val_accuracy: 0.9232
# Epoch 147/150
# 175/175 [==============================] - 3s 17ms/step - loss: 0.0833 - accuracy: 0.9683 - val_loss: 0.2375 - val_accuracy: 0.9285
# Epoch 148/150
# 175/175 [==============================] - 2s 12ms/step - loss: 0.0790 - accuracy: 0.9693 - val_loss: 0.1984 - val_accuracy: 0.9303
# Epoch 149/150
# 175/175 [==============================] - 3s 17ms/step - loss: 0.0788 - accuracy: 0.9713 - val_loss: 0.2272 - val_accuracy: 0.9289
# Epoch 150/150
# 175/175 [==============================] - 2s 13ms/step - loss: 0.0748 - accuracy: 0.9731 - val_loss: 0.2075 - val_accuracy: 0.9285

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.1944 - accuracy: 0.9285
# Test Accuracy: 92.8510%
