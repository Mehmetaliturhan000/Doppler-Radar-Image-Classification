# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Basic Neural Network (4 Dense Layers)

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 1.8148 - accuracy: 0.3762 - val_loss: 0.9762 - val_accuracy: 0.4017
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0534 - accuracy: 0.4395 - val_loss: 1.5538 - val_accuracy: 0.3299
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0092 - accuracy: 0.4653 - val_loss: 0.9762 - val_accuracy: 0.3949
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.9488 - accuracy: 0.5123 - val_loss: 0.8726 - val_accuracy: 0.5647
# Epoch 5/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0402 - accuracy: 0.4337 - val_loss: 1.0929 - val_accuracy: 0.3892
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0927 - accuracy: 0.3823 - val_loss: 1.0914 - val_accuracy: 0.3892
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 11/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 12/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 13/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 14/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 15/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 16/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 17/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 18/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 19/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 20/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 21/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 22/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 23/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 24/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 25/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 26/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 27/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 28/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 29/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 30/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 31/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 32/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 33/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0912 - val_accuracy: 0.3892
# Epoch 34/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 35/50
# 350/350 [==============================] - 1s 3ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 36/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 37/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 38/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0911 - val_accuracy: 0.3892
# Epoch 39/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 40/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 41/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 42/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 43/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 44/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 45/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 46/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 47/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 48/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0921 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 1.0922 - accuracy: 0.3823 - val_loss: 1.0910 - val_accuracy: 0.3892

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 1.0927 - accuracy: 0.3812
# Test Accuracy: 38.1184%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Dense Layer (64)
# ### Dense Layer (64)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 9, 59, 32)         320
#
#  flatten_1 (Flatten)         (None, 16992)             0
#
#  dense_5 (Dense)             (None, 64)                1087552
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,096,387
# Trainable params: 1,096,387
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=32)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 18s 51ms/step - loss: 1.5923 - accuracy: 0.7458 - val_loss: 0.3365 - val_accuracy: 0.8560
# Epoch 2/50
# 350/350 [==============================] - 17s 50ms/step - loss: 0.2913 - accuracy: 0.8916 - val_loss: 0.3065 - val_accuracy: 0.8753
# Epoch 3/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.2501 - accuracy: 0.9066 - val_loss: 0.2654 - val_accuracy: 0.9021
# Epoch 4/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.2237 - accuracy: 0.9154 - val_loss: 0.2747 - val_accuracy: 0.8978
# Epoch 5/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2190 - accuracy: 0.9157 - val_loss: 0.2935 - val_accuracy: 0.8924
# Epoch 6/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.2116 - accuracy: 0.9180 - val_loss: 0.2682 - val_accuracy: 0.8939
# Epoch 7/50
# 350/350 [==============================] - 17s 50ms/step - loss: 0.2020 - accuracy: 0.9230 - val_loss: 0.3162 - val_accuracy: 0.8856
# Epoch 8/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1886 - accuracy: 0.9243 - val_loss: 0.2728 - val_accuracy: 0.9028
# Epoch 9/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1524 - accuracy: 0.9407 - val_loss: 0.2608 - val_accuracy: 0.9010
# Epoch 10/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.1709 - accuracy: 0.9344 - val_loss: 0.3123 - val_accuracy: 0.8949
# Epoch 11/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.1334 - accuracy: 0.9460 - val_loss: 0.3199 - val_accuracy: 0.9003
# Epoch 12/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.1221 - accuracy: 0.9510 - val_loss: 0.2953 - val_accuracy: 0.8996
# Epoch 13/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.1115 - accuracy: 0.9558 - val_loss: 0.2872 - val_accuracy: 0.8942
# Epoch 14/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.1013 - accuracy: 0.9609 - val_loss: 0.3924 - val_accuracy: 0.9014
# Epoch 15/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1166 - accuracy: 0.9529 - val_loss: 0.3134 - val_accuracy: 0.9028
# Epoch 16/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0847 - accuracy: 0.9673 - val_loss: 0.3253 - val_accuracy: 0.8996
# Epoch 17/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0835 - accuracy: 0.9688 - val_loss: 0.3543 - val_accuracy: 0.9089
# Epoch 18/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0954 - accuracy: 0.9637 - val_loss: 0.4031 - val_accuracy: 0.8724
# Epoch 19/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.1144 - accuracy: 0.9552 - val_loss: 0.3309 - val_accuracy: 0.8996
# Epoch 20/50
# 350/350 [==============================] - 17s 50ms/step - loss: 0.0957 - accuracy: 0.9623 - val_loss: 0.3515 - val_accuracy: 0.9056
# Epoch 21/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.0894 - accuracy: 0.9680 - val_loss: 0.4031 - val_accuracy: 0.8685
# Epoch 22/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.0719 - accuracy: 0.9731 - val_loss: 0.3936 - val_accuracy: 0.8956
# Epoch 23/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0552 - accuracy: 0.9800 - val_loss: 0.4549 - val_accuracy: 0.8953
# Epoch 24/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0680 - accuracy: 0.9728 - val_loss: 0.3880 - val_accuracy: 0.9024
# Epoch 25/50
# 350/350 [==============================] - 15s 43ms/step - loss: 0.0725 - accuracy: 0.9728 - val_loss: 0.3812 - val_accuracy: 0.8806
# Epoch 26/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1152 - accuracy: 0.9530 - val_loss: 0.3299 - val_accuracy: 0.8949
# Epoch 27/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.0912 - accuracy: 0.9660 - val_loss: 0.3584 - val_accuracy: 0.8824
# Epoch 28/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0795 - accuracy: 0.9710 - val_loss: 0.3460 - val_accuracy: 0.9124
# Epoch 29/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0538 - accuracy: 0.9809 - val_loss: 0.4525 - val_accuracy: 0.8974
# Epoch 30/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0506 - accuracy: 0.9805 - val_loss: 0.4425 - val_accuracy: 0.8885
# Epoch 31/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0480 - accuracy: 0.9815 - val_loss: 0.4537 - val_accuracy: 0.8992
# Epoch 32/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0541 - accuracy: 0.9803 - val_loss: 0.4406 - val_accuracy: 0.8992
# Epoch 33/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0276 - accuracy: 0.9901 - val_loss: 0.4594 - val_accuracy: 0.8856
# Epoch 34/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0387 - accuracy: 0.9859 - val_loss: 0.5748 - val_accuracy: 0.8892
# Epoch 35/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0478 - accuracy: 0.9828 - val_loss: 0.4884 - val_accuracy: 0.8753
# Epoch 36/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0443 - accuracy: 0.9850 - val_loss: 0.5641 - val_accuracy: 0.8935
# Epoch 37/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.4637 - val_accuracy: 0.8917
# Epoch 38/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.5647 - val_accuracy: 0.8903
# Epoch 39/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.0700 - accuracy: 0.9756 - val_loss: 0.4515 - val_accuracy: 0.8942
# Epoch 40/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.5386 - val_accuracy: 0.9010
# Epoch 41/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.5655 - val_accuracy: 0.8992
# Epoch 42/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 0.5505 - val_accuracy: 0.8910
# Epoch 43/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0644 - accuracy: 0.9772 - val_loss: 0.7306 - val_accuracy: 0.8585
# Epoch 44/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.6040 - val_accuracy: 0.8910
# Epoch 45/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0293 - accuracy: 0.9902 - val_loss: 0.5457 - val_accuracy: 0.8999
# Epoch 46/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.0304 - accuracy: 0.9890 - val_loss: 0.5141 - val_accuracy: 0.8974
# Epoch 47/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.4985 - val_accuracy: 0.8996
# Epoch 48/50
# 350/350 [==============================] - 14s 39ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.8069 - val_accuracy: 0.8606
# Epoch 49/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.0524 - accuracy: 0.9833 - val_loss: 0.5217 - val_accuracy: 0.8992
# Epoch 50/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.7791 - val_accuracy: 0.8960

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 3s 30ms/step - loss: 0.7585 - accuracy: 0.9013
# Test Accuracy: 90.1344%
