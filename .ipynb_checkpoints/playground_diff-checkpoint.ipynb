# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=31, shuffle=True)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 9, 59, 32)         320
#
#  average_pooling2d_4 (Averag  (None, 4, 29, 32)        0
#  ePooling2D)
#
#  dropout_8 (Dropout)         (None, 4, 29, 32)         0
#
#  conv2d_5 (Conv2D)           (None, 2, 27, 64)         18496
#
#  average_pooling2d_5 (Averag  (None, 1, 13, 64)        0
#  ePooling2D)
#
#  dropout_9 (Dropout)         (None, 1, 13, 64)         0
#
#  flatten_3 (Flatten)         (None, 832)               0
#
#  dense_13 (Dense)            (None, 64)                53312
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 64)                4160
#
#  dense_16 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 80,643
# Trainable params: 80,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=64)
# Out:
# Epoch 1/50
# 175/175 [==============================] - 4s 17ms/step - loss: 1.1652 - accuracy: 0.3701 - val_loss: 1.0852 - val_accuracy: 0.3888
# Epoch 2/50
# 175/175 [==============================] - 2s 14ms/step - loss: 1.0786 - accuracy: 0.3832 - val_loss: 1.0005 - val_accuracy: 0.5189
# Epoch 3/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.8720 - accuracy: 0.5546 - val_loss: 0.6760 - val_accuracy: 0.6630
# Epoch 4/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.6269 - accuracy: 0.6942 - val_loss: 0.3822 - val_accuracy: 0.8542
# Epoch 5/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4497 - accuracy: 0.8108 - val_loss: 0.3672 - val_accuracy: 0.8413
# Epoch 6/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3860 - accuracy: 0.8390 - val_loss: 0.2688 - val_accuracy: 0.8992
# Epoch 7/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3507 - accuracy: 0.8566 - val_loss: 0.2442 - val_accuracy: 0.9071
# Epoch 8/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3210 - accuracy: 0.8677 - val_loss: 0.2677 - val_accuracy: 0.8856
# Epoch 9/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3040 - accuracy: 0.8767 - val_loss: 0.2617 - val_accuracy: 0.8939
# Epoch 10/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3051 - accuracy: 0.8731 - val_loss: 0.2290 - val_accuracy: 0.9121
# Epoch 11/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2925 - accuracy: 0.8789 - val_loss: 0.2295 - val_accuracy: 0.9142
# Epoch 12/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2882 - accuracy: 0.8786 - val_loss: 0.2511 - val_accuracy: 0.8935
# Epoch 13/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2882 - accuracy: 0.8832 - val_loss: 0.2304 - val_accuracy: 0.9028
# Epoch 14/50
# 175/175 [==============================] - 3s 18ms/step - loss: 0.2657 - accuracy: 0.8887 - val_loss: 0.1950 - val_accuracy: 0.9267
# Epoch 15/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2676 - accuracy: 0.8911 - val_loss: 0.2045 - val_accuracy: 0.9257
# Epoch 16/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2692 - accuracy: 0.8891 - val_loss: 0.2037 - val_accuracy: 0.9228
# Epoch 17/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2633 - accuracy: 0.8929 - val_loss: 0.1940 - val_accuracy: 0.9264
# Epoch 18/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2506 - accuracy: 0.8979 - val_loss: 0.1885 - val_accuracy: 0.9328
# Epoch 19/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2491 - accuracy: 0.8949 - val_loss: 0.2267 - val_accuracy: 0.9071
# Epoch 20/50
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2657 - accuracy: 0.8907 - val_loss: 0.1988 - val_accuracy: 0.9224
# Epoch 21/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2366 - accuracy: 0.9023 - val_loss: 0.1772 - val_accuracy: 0.9367
# Epoch 22/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2467 - accuracy: 0.8980 - val_loss: 0.1990 - val_accuracy: 0.9214
# Epoch 23/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2357 - accuracy: 0.9060 - val_loss: 0.1832 - val_accuracy: 0.9332
# Epoch 24/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2441 - accuracy: 0.8997 - val_loss: 0.1932 - val_accuracy: 0.9289
# Epoch 25/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2321 - accuracy: 0.9054 - val_loss: 0.1683 - val_accuracy: 0.9385
# Epoch 26/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2249 - accuracy: 0.9091 - val_loss: 0.1765 - val_accuracy: 0.9325
# Epoch 27/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2368 - accuracy: 0.9044 - val_loss: 0.1762 - val_accuracy: 0.9325
# Epoch 28/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2227 - accuracy: 0.9094 - val_loss: 0.1904 - val_accuracy: 0.9264
# Epoch 29/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2256 - accuracy: 0.9071 - val_loss: 0.2070 - val_accuracy: 0.9199
# Epoch 30/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2204 - accuracy: 0.9091 - val_loss: 0.1692 - val_accuracy: 0.9360
# Epoch 31/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2199 - accuracy: 0.9099 - val_loss: 0.1832 - val_accuracy: 0.9235
# Epoch 32/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2177 - accuracy: 0.9136 - val_loss: 0.1638 - val_accuracy: 0.9403
# Epoch 33/50
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2180 - accuracy: 0.9135 - val_loss: 0.1774 - val_accuracy: 0.9367
# Epoch 34/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2181 - accuracy: 0.9081 - val_loss: 0.1661 - val_accuracy: 0.9346
# Epoch 35/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2207 - accuracy: 0.9104 - val_loss: 0.1854 - val_accuracy: 0.9210
# Epoch 36/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2129 - accuracy: 0.9130 - val_loss: 0.1646 - val_accuracy: 0.9382
# Epoch 37/50
# 175/175 [==============================] - 3s 19ms/step - loss: 0.2226 - accuracy: 0.9083 - val_loss: 0.1775 - val_accuracy: 0.9346
# Epoch 38/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2216 - accuracy: 0.9115 - val_loss: 0.1656 - val_accuracy: 0.9414
# Epoch 39/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2144 - accuracy: 0.9116 - val_loss: 0.1902 - val_accuracy: 0.9253
# Epoch 40/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2145 - accuracy: 0.9121 - val_loss: 0.1631 - val_accuracy: 0.9385
# Epoch 41/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2136 - accuracy: 0.9145 - val_loss: 0.1656 - val_accuracy: 0.9385
# Epoch 42/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2123 - accuracy: 0.9109 - val_loss: 0.1750 - val_accuracy: 0.9317
# Epoch 43/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2112 - accuracy: 0.9152 - val_loss: 0.1570 - val_accuracy: 0.9403
# Epoch 44/50
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2066 - accuracy: 0.9162 - val_loss: 0.1562 - val_accuracy: 0.9389
# Epoch 45/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2002 - accuracy: 0.9180 - val_loss: 0.1576 - val_accuracy: 0.9439
# Epoch 46/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.1971 - accuracy: 0.9211 - val_loss: 0.1664 - val_accuracy: 0.9360
# Epoch 47/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2106 - accuracy: 0.9147 - val_loss: 0.1693 - val_accuracy: 0.9346
# Epoch 48/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.1978 - accuracy: 0.9218 - val_loss: 0.1654 - val_accuracy: 0.9403
# Epoch 49/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.1979 - accuracy: 0.9148 - val_loss: 0.1656 - val_accuracy: 0.9385
# Epoch 50/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.1990 - accuracy: 0.9205 - val_loss: 0.1568 - val_accuracy: 0.9417

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1663 - accuracy: 0.9351
# Test Accuracy: 93.5087%
