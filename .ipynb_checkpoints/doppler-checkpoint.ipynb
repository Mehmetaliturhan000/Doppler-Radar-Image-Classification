# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
##Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf # tensorflow

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(11,61)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 3ms/step - loss: 2.7114 - accuracy: 0.4500 - val_loss: 0.8450 - val_accuracy: 0.5693
# Epoch 2/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.8525 - accuracy: 0.6298 - val_loss: 0.5660 - val_accuracy: 0.8095
# Epoch 3/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.6921 - accuracy: 0.7010 - val_loss: 0.5805 - val_accuracy: 0.7616
# Epoch 4/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.5883 - accuracy: 0.7510 - val_loss: 0.5800 - val_accuracy: 0.7480
# Epoch 5/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.5800 - accuracy: 0.7605 - val_loss: 0.4224 - val_accuracy: 0.8517
# Epoch 6/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.5248 - accuracy: 0.7847 - val_loss: 0.4459 - val_accuracy: 0.8295
# Epoch 7/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.5626 - accuracy: 0.7651 - val_loss: 0.4370 - val_accuracy: 0.8503
# Epoch 8/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.5792 - accuracy: 0.7577 - val_loss: 0.7056 - val_accuracy: 0.6244
# Epoch 9/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.5164 - accuracy: 0.7915 - val_loss: 0.4363 - val_accuracy: 0.8367
# Epoch 10/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.4566 - accuracy: 0.8113 - val_loss: 0.4700 - val_accuracy: 0.8041
# Epoch 11/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.
50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3283 - accuracy: 0.8747 - val_loss: 0.2863 - val_accuracy: 0.8996
# Epoch 48/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8729 - val_loss: 0.4155 - val_accuracy: 0.8399
# Epoch 49/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3347 - accuracy: 0.8719 - val_loss: 0.2874 - val_accuracy: 0.8931
# Epoch 50/50
# 350/350 [==============================] - 1s 2ms/step - loss: 0.3241 - accuracy: 0.8764 - val_loss: 0.3609 - val_accuracy: 0.8545

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 1ms/step - loss: 0.3663 - accuracy: 0.8562
# Test Accuracy: 85.6162%

# %% [markdown]
# # Displaying Images and Their Predictions

# %%
def get_key_from_value(search_value , dict_to_look = CLASS):
    for k, v in dict_to_look.items():
        if v == search_value:
            return k

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.jet, aspect='auto')
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(get_key_from_value(predicted_label),
                                100*np.max(predictions_array),
                                get_key_from_value(true_label)),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(3))
    plt.yticks([])
    thisplot = plt.bar(range(3), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

probability_model = tf.keras.Sequential([model, 
                                     tf.keras.layers.Softmax()])
predictions = probability_model.predict(x_test)
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
j = np.random.choice(len(x_test),num_images) # choose 5*3 at random
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(j[i], predictions[j[i]], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(j[i], predictions[j[i]], y_test)
plt.tight_layout()
plt.show()
# Out:
# 110/110 [==============================] - 0s 1ms/step

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
import tensorflow.keras as k

model=k.Sequential()
model.add(tf.keras.Input(shape=(11,61,1)))
model.add(k.layers.Conv2D(32,3,3,padding='valid',
    dilation_rate=(1, 1),
    activation="relu"))
model.add(k.layers.Flatten())
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(3,activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 3, 20, 32)         320
#
#  flatten_1 (Flatten)         (None, 1920)              0
#
#  dense_5 (Dense)             (None, 64)                122944
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 131,779
# Trainable params: 131,779
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 3s 6ms/step - loss: 0.8189 - accuracy: 0.6541 - val_loss: 0.4520 - val_accuracy: 0.8295
# Epoch 2/50
# 350/350 [==============================] - 3s 8ms/step - loss: 0.4242 - accuracy: 0.8325 - val_loss: 0.3744 - val_accuracy: 0.8467
# Epoch 3/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3778 - accuracy: 0.8496 - val_loss: 0.4597 - val_accuracy: 0.8227
# Epoch 4/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3728 - accuracy: 0.8507 - val_loss: 0.3942 - val_accuracy: 0.8417
# Epoch 5/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.3527 - accuracy: 0.8584 - val_loss: 0.3613 - val_accuracy: 0.8567
# Epoch 6/50
# 350/350 [==============================] - 2s 4ms/step - loss: 0.3525 - accuracy: 0.8575 - val_loss: 0.3696 - val_accuracy: 0.8506
# Epoch 7/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3348 - accuracy: 0.8643 - val_loss: 0.3436 - val_accuracy: 0.8595
# Epoch 8/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.3286 - accuracy: 0.8661 - val_loss: 0.3197 - val_accuracy: 0.8756
# Epoch 9/50
# 350/350 [==============================] - 3s 7ms/step - loss: 0.3058 - accuracy: 0.8765 - val_loss: 0.3870 - val_accuracy: 0.8377
# Epoch 10/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.3185 - accuracy: 0.8693 - val_loss: 0.3515 - val_accuracy: 0.8574
# Epoch 11/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.3195 - accuracy: 0.8689 - val_loss: 0.3399 - val_accuracy: 0.8735
# Epoch 12/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3062 - accuracy: 0.8786 - val_loss: 0.3144 - val_accuracy: 0.8738
# Epoch 13/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.
50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1982 - accuracy: 0.9213 - val_loss: 0.2508 - val_accuracy: 0.9114
# Epoch 44/50
# 350/350 [==============================] - 3s 8ms/step - loss: 0.1835 - accuracy: 0.9277 - val_loss: 0.3252 - val_accuracy: 0.8846
# Epoch 45/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.1910 - accuracy: 0.9240 - val_loss: 0.3460 - val_accuracy: 0.8653
# Epoch 46/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.1845 - accuracy: 0.9298 - val_loss: 0.2369 - val_accuracy: 0.9167
# Epoch 47/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1795 - accuracy: 0.9316 - val_loss: 0.2710 - val_accuracy: 0.9049
# Epoch 48/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1814 - accuracy: 0.9291 - val_loss: 0.2799 - val_accuracy: 0.9010
# Epoch 49/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1715 - accuracy: 0.9330 - val_loss: 0.2384 - val_accuracy: 0.9192
# Epoch 50/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1856 - accuracy: 0.9288 - val_loss: 0.2845 - val_accuracy: 0.9035

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.2886 - accuracy: 0.8910
# Test Accuracy: 89.1049%

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
import tensorflow.keras as k

model=k.Sequential()
model.add(tf.keras.Input(shape=(11,61,1)))
model.add(k.layers.Conv2D(32,3,3,padding='valid',
    dilation_rate=(1, 1),
    activation="relu"))
model.add(k.layers.Flatten())
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(3,activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 3, 20, 32)         320
#
#  flatten_2 (Flatten)         (None, 1920)              0
#
#  dense_9 (Dense)             (None, 64)                122944
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 64)                4160
#
#  dense_12 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 131,779
# Trainable params: 131,779
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2, batch_size=8)
# Out:
# Epoch 1/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.7171 - accuracy: 0.7247 - val_loss: 0.4804 - val_accuracy: 0.8134
# Epoch 2/50
# 1399/1399 [==============================] - 6s 5ms/step - loss: 0.4607 - accuracy: 0.8147 - val_loss: 0.5411 - val_accuracy: 0.8156
# Epoch 3/50
# 1399/1399 [==============================] - 7s 5ms/step - loss: 0.4215 - accuracy: 0.8289 - val_loss: 0.4489 - val_accuracy: 0.8310
# Epoch 4/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.3961 - accuracy: 0.8414 - val_loss: 0.3598 - val_accuracy: 0.8635
# Epoch 5/50
# 1399/1399 [==============================] - 8s 6ms/step - loss: 0.3569 - accuracy: 0.8584 - val_loss: 0.3973 - val_accuracy: 0.8492
# Epoch 6/50
# 1399/1399 [==============================] - 7s 5ms/step - loss: 0.3373 - accuracy: 0.8629 - val_loss: 0.3211 - val_accuracy: 0.8692
# Epoch 7/50
# 1399/1399 [==============================] - 7s 5ms/step - loss: 0.3198 - accuracy: 0.8668 - val_loss: 0.3298 - val_accuracy: 0.8638
# Epoch 8/50
# 1399/1399 [==============================] - 7s 5ms/step - loss: 0.3063 - accuracy: 0.8748 - val_loss: 0.3372 - val_accuracy: 0.8667
# Epoch 9/50
# 1399/1399 [==============================] - 7s 5ms/step - loss: 0.2937 - accuracy: 0.8812 - val_loss: 0.4344 - val_accuracy: 0.8281
# Epoch 10/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.2886 - accuracy: 0.8813 - val_loss: 0.3290 - val_accuracy: 0.8710
# Epoch 11/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.2712 - accuracy: 0.8883 - val_loss: 0.3147 - val_accuracy: 0.8788
# Epoch 12/50
# 1399/1399 [==============================] - 7s 5ms/step - loss: 0.2636 - accuracy: 0.8912 - val_loss: 0.3620 - val_accuracy: 0.8542
# Epoch 13/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.2572 - accuracy: 0.8964 - val_loss: 0.3594 - val_accuracy: 0.8645
# Epoch 14/50
# 1399/1399 [==============================] - 5s 4ms/step - loss: 0.2588 - accuracy: 0.8962 - val_loss: 0.3179 - val_accuracy: 0.8813
# Epoch 15/50
# 1399/1399 [==============================] - 8s 6ms/step - loss: 0.2514 - accuracy: 0.8991 - val_loss: 0.3508 - val_accuracy: 0.8688
# Epoch 16/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0
50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.0870 - accuracy: 0.9668 - val_loss: 0.6397 - val_accuracy: 0.8624
# Epoch 44/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.0821 - accuracy: 0.9691 - val_loss: 0.8084 - val_accuracy: 0.8510
# Epoch 45/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.0978 - accuracy: 0.9645 - val_loss: 0.7425 - val_accuracy: 0.8628
# Epoch 46/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.0966 - accuracy: 0.9661 - val_loss: 0.6913 - val_accuracy: 0.8588
# Epoch 47/50
# 1399/1399 [==============================] - 9s 6ms/step - loss: 0.0887 - accuracy: 0.9695 - val_loss: 0.6902 - val_accuracy: 0.8642
# Epoch 48/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.0775 - accuracy: 0.9718 - val_loss: 0.7135 - val_accuracy: 0.8374
# Epoch 49/50
# 1399/1399 [==============================] - 8s 5ms/step - loss: 0.0803 - accuracy: 0.9710 - val_loss: 0.6037 - val_accuracy: 0.8710
# Epoch 50/50
# 1399/1399 [==============================] - 6s 4ms/step - loss: 0.0826 - accuracy: 0.9698 - val_loss: 0.6975 - val_accuracy: 0.8513

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.7195 - accuracy: 0.8456
# Test Accuracy: 84.5582%

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
import tensorflow.keras as k

model=k.Sequential()
model.add(tf.keras.Input(shape=(11,61,1)))
model.add(k.layers.Conv2D(32,3,3,padding='valid',
    dilation_rate=(1, 1),
    activation="relu"))
model.add(k.layers.Flatten())
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(3,activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 3, 20, 32)         320
#
#  flatten_3 (Flatten)         (None, 1920)              0
#
#  dense_13 (Dense)            (None, 64)                122944
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dense_15 (Dense)            (None, 64)                4160
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dense_17 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 135,939
# Trainable params: 135,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 3s 7ms/step - loss: 0.8103 - accuracy: 0.6336 - val_loss: 0.5055 - val_accuracy: 0.7487
# Epoch 2/50
# 350/350 [==============================] - 3s 8ms/step - loss: 0.4417 - accuracy: 0.8155 - val_loss: 0.4512 - val_accuracy: 0.8074
# Epoch 3/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.3825 - accuracy: 0.8469 - val_loss: 0.3839 - val_accuracy: 0.8510
# Epoch 4/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3744 - accuracy: 0.8491 - val_loss: 0.3504 - val_accuracy: 0.8642
# Epoch 5/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.3383 - accuracy: 0.8668 - val_loss: 0.3261 - val_accuracy: 0.8724
# Epoch 6/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3221 - accuracy: 0.8688 - val_loss: 0.3140 - val_accuracy: 0.8778
# Epoch 7/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.3192 - accuracy: 0.8723 - val_loss: 0.3695 - val_accuracy: 0.8592
# Epoch 8/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.3138 - accuracy: 0.8718 - val_loss: 0.2995 - val_accuracy: 0.8778
# Epoch 9/50
# 350/350 [==============================] - 2s 7ms/step - loss: 0.2872 - accuracy: 0.8839 - val_loss: 0.3338 - val_accuracy: 0.8663
# Epoch 10/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.2941 - accuracy: 0.8804 - val_loss: 0.3404 - val_accuracy: 0.8663
# Epoch 11/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.2978 - accuracy: 0.8811 - val_loss: 0.3553 - val_accuracy: 0.8481
# Epoch 12/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.2994 - accuracy: 0.8752 - val_loss: 0.3579 - val_accuracy: 0.8642
# Epoch 13/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.2889 - accuracy: 0.8836 - val_loss: 0.3004 - val_accuracy: 0.8821
# Epoch 14/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.2812 - accuracy: 0.8863 - val_loss: 0.3067 - val_accuracy: 0.8867
# Epoch 15/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.2884 - accuracy: 0.8820 - val_loss: 0.3712 - val_accuracy: 0.8531
# Epoch 16/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.
50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1732 - accuracy: 0.9318 - val_loss: 0.3344 - val_accuracy: 0.8949
# Epoch 46/50
# 350/350 [==============================] - 2s 6ms/step - loss: 0.1724 - accuracy: 0.9298 - val_loss: 0.3154 - val_accuracy: 0.9006
# Epoch 47/50
# 350/350 [==============================] - 2s 4ms/step - loss: 0.1722 - accuracy: 0.9340 - val_loss: 0.3568 - val_accuracy: 0.8835
# Epoch 48/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.1702 - accuracy: 0.9332 - val_loss: 0.3347 - val_accuracy: 0.8967
# Epoch 49/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1716 - accuracy: 0.9335 - val_loss: 0.3549 - val_accuracy: 0.8960
# Epoch 50/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.1494 - accuracy: 0.9423 - val_loss: 0.3197 - val_accuracy: 0.8906

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8808
# Test Accuracy: 88.0755%

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation
import tensorflow.keras as k

model=k.Sequential()
model.add(tf.keras.Input(shape=(11,61,1)))
model.add(k.layers.Conv2D(32,3,3,padding='valid',
    dilation_rate=(1, 1),
    activation="relu"))
model.add(k.layers.MaxPooling2D(2,2))
model.add(k.layers.Flatten())
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(64,activation="relu"))
model.add(k.layers.Dense(3,activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 3, 20, 32)         320
#
#  max_pooling2d (MaxPooling2D  (None, 1, 10, 32)        0
#  )
#
#  flatten_4 (Flatten)         (None, 320)               0
#
#  dense_18 (Dense)            (None, 64)                20544
#
#  dense_19 (Dense)            (None, 64)                4160
#
#  dense_20 (Dense)            (None, 64)                4160
#
#  dense_21 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 29,379
# Trainable params: 29,379
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 350/350 [==============================] - 2s 4ms/step - loss: 1.3471 - accuracy: 0.4335 - val_loss: 0.9407 - val_accuracy: 0.5633
# Epoch 2/50
# 350/350 [==============================] - 2s 5ms/step - loss: 0.8237 - accuracy: 0.6191 - val_loss: 0.9440 - val_accuracy: 0.5325
# Epoch 3/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.6777 - accuracy: 0.6869 - val_loss: 0.8372 - val_accuracy: 0.6197
# Epoch 4/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.5885 - accuracy: 0.7373 - val_loss: 0.6221 - val_accuracy: 0.7252
# Epoch 5/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.5565 - accuracy: 0.7540 - val_loss: 0.6756 - val_accuracy: 0.6733
# Epoch 6/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.5260 - accuracy: 0.7703 - val_loss: 0.4803 - val_accuracy: 0.7941
# Epoch 7/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.4893 - accuracy: 0.7842 - val_loss: 0.5212 - val_accuracy: 0.7795
# Epoch 8/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.4879 - accuracy: 0.7919 - val_loss: 0.4579 - val_accuracy: 0.7956
# Epoch 9/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.4662 - accuracy: 0.7996 - val_loss: 0.4543 - val_accuracy: 0.7966
# Epoch 10/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.4573 - accuracy: 0.8025 - val_loss: 0.4485 - val_accuracy: 0.8102
# Epoch 11/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.4630 - accuracy: 0.7971 - val_loss: 0.4722 - val_accuracy: 0.7970
# Epoch 12/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.4598 - accuracy: 0.7996 - val_loss: 0.4681 - val_accuracy: 0.8063
# Epoch 13/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.4545 - accuracy: 0.8038 - val_loss: 0.4671 - val_accuracy: 0.8009
# Epoch 14/50
# 350/350 [==============================] - 2s 4ms/step - loss: 0.4460 - accuracy: 0.8066 - val_loss: 0.4449 - val_accuracy: 0.8113
# Epoch 15/50
# 350/350 [==============================] - 1s 3ms/step - loss: 0.4404 - accuracy: 0.8076 - val_loss: 0.4383 - val_accuracy: 0.8074
# Epoch 16/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.4360 - accuracy: 0.8113 - val_loss: 0.4502 - val_accuracy: 0.8059
# Epoch 17/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.4354 - accuracy: 0.8125 - val_loss: 0.4656 - val_accuracy: 0.7881
# Epoch 18/50
# 350/350 [==============================] - 1s 4ms/step - loss: 0.