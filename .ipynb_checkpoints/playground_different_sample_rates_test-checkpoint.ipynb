# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=3, shuffle=True)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 9, 59, 32)         320
#
#  average_pooling2d (AverageP  (None, 4, 29, 32)        0
#  ooling2D)
#
#  dropout (Dropout)           (None, 4, 29, 32)         0
#
#  conv2d_1 (Conv2D)           (None, 2, 27, 64)         18496
#
#  average_pooling2d_1 (Averag  (None, 1, 13, 64)        0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 13, 64)         0
#
#  flatten (Flatten)           (None, 832)               0
#
#  dense (Dense)               (None, 64)                53312
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 80,643
# Trainable params: 80,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=64)
# Out:
# Epoch 1/50
# 175/175 [==============================] - 4s 18ms/step - loss: 1.4160 - accuracy: 0.3618 - val_loss: 1.0930 - val_accuracy: 0.3888
# Epoch 2/50
# 175/175 [==============================] - 3s 17ms/step - loss: 1.0857 - accuracy: 0.3756 - val_loss: 1.0310 - val_accuracy: 0.3888
# Epoch 3/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.8912 - accuracy: 0.5408 - val_loss: 0.7322 - val_accuracy: 0.6583
# Epoch 4/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.7523 - accuracy: 0.6367 - val_loss: 0.6741 - val_accuracy: 0.6794
# Epoch 5/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.6691 - accuracy: 0.6877 - val_loss: 0.4058 - val_accuracy: 0.8470
# Epoch 6/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4801 - accuracy: 0.7976 - val_loss: 0.3478 - val_accuracy: 0.8678
# Epoch 7/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.4516 - accuracy: 0.8145 - val_loss: 0.6164 - val_accuracy: 0.7416
# Epoch 8/50
# 175/175 [==============================] - 3s 17ms/step - loss: 0.4775 - accuracy: 0.8040 - val_loss: 0.2796 - val_accuracy: 0.8974
# Epoch 9/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.3889 - accuracy: 0.8416 - val_loss: 0.4064 - val_accuracy: 0.8184
# Epoch 10/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3633 - accuracy: 0.8521 - val_loss: 0.2454 - val_accuracy: 0.9117
# Epoch 11/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3403 - accuracy: 0.8610 - val_loss: 0.2821 - val_accuracy: 0.9031
# Epoch 12/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3278 - accuracy: 0.8663 - val_loss: 0.2400 - val_accuracy: 0.9121
# Epoch 13/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3099 - accuracy: 0.8747 - val_loss: 0.2220 - val_accuracy: 0.9203
# Epoch 14/50
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3065 - accuracy: 0.8744 - val_loss: 0.2140 - val_accuracy: 0.9235
# Epoch 15/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2916 - accuracy: 0.8842 - val_loss: 0.2196 - val_accuracy: 0.9157
# Epoch 16/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2929 - accuracy: 0.8808 - val_loss: 0.2107 - val_accuracy: 0.9171
# Epoch 17/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2807 - accuracy: 0.8856 - val_loss: 0.2192 - val_accuracy: 0.9117
# Epoch 18/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2762 - accuracy: 0.8874 - val_loss: 0.1935 - val_accuracy: 0.9246
# Epoch 19/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2651 - accuracy: 0.8901 - val_loss: 0.2735 - val_accuracy: 0.8824
# Epoch 20/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2699 - accuracy: 0.8900 - val_loss: 0.2235 - val_accuracy: 0.9142
# Epoch 21/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2612 - accuracy: 0.8893 - val_loss: 0.2199 - val_accuracy: 0.9149
# Epoch 22/50
# 175/175 [==============================] - 3s 18ms/step - loss: 0.2652 - accuracy: 0.8940 - val_loss: 0.1783 - val_accuracy: 0.9321
# Epoch 23/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2616 - accuracy: 0.8919 - val_loss: 0.1989 - val_accuracy: 0.9232
# Epoch 24/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2488 - accuracy: 0.8995 - val_loss: 0.2187 - val_accuracy: 0.9078
# Epoch 25/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2459 - accuracy: 0.8988 - val_loss: 0.1832 - val_accuracy: 0.9339
# Epoch 26/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2439 - accuracy: 0.9004 - val_loss: 0.1801 - val_accuracy: 0.9335
# Epoch 27/50
# 175/175 [==============================] - 4s 23ms/step - loss: 0.2378 - accuracy: 0.9023 - val_loss: 0.2215 - val_accuracy: 0.9046
# Epoch 28/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2490 - accuracy: 0.8983 - val_loss: 0.2083 - val_accuracy: 0.9260
# Epoch 29/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2431 - accuracy: 0.9057 - val_loss: 0.2006 - val_accuracy: 0.9257
# Epoch 30/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2374 - accuracy: 0.9036 - val_loss: 0.1701 - val_accuracy: 0.9378
# Epoch 31/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2412 - accuracy: 0.9029 - val_loss: 0.2104 - val_accuracy: 0.9185
# Epoch 32/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2371 - accuracy: 0.9029 - val_loss: 0.2066 - val_accuracy: 0.9253
# Epoch 33/50
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2329 - accuracy: 0.9042 - val_loss: 0.1726 - val_accuracy: 0.9350
# Epoch 34/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2259 - accuracy: 0.9072 - val_loss: 0.1814 - val_accuracy: 0.9335
# Epoch 35/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.2316 - accuracy: 0.9028 - val_loss: 0.1976 - val_accuracy: 0.9260
# Epoch 36/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2284 - accuracy: 0.9043 - val_loss: 0.1920 - val_accuracy: 0.9264
# Epoch 37/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2204 - accuracy: 0.9101 - val_loss: 0.1724 - val_accuracy: 0.9360
# Epoch 38/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2173 - accuracy: 0.9126 - val_loss: 0.1801 - val_accuracy: 0.9310
# Epoch 39/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2181 - accuracy: 0.9144 - val_loss: 0.1600 - val_accuracy: 0.9375
# Epoch 40/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2230 - accuracy: 0.9096 - val_loss: 0.1809 - val_accuracy: 0.9289
# Epoch 41/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2208 - accuracy: 0.9098 - val_loss: 0.1658 - val_accuracy: 0.9378
# Epoch 42/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2203 - accuracy: 0.9105 - val_loss: 0.1715 - val_accuracy: 0.9382
# Epoch 43/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.2317 - accuracy: 0.9032 - val_loss: 0.1769 - val_accuracy: 0.9289
# Epoch 44/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.2180 - accuracy: 0.9130 - val_loss: 0.1742 - val_accuracy: 0.9332
# Epoch 45/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2160 - accuracy: 0.9129 - val_loss: 0.1936 - val_accuracy: 0.9210
# Epoch 46/50
# 175/175 [==============================] - 3s 18ms/step - loss: 0.2081 - accuracy: 0.9169 - val_loss: 0.1614 - val_accuracy: 0.9364
# Epoch 47/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2123 - accuracy: 0.9120 - val_loss: 0.2204 - val_accuracy: 0.8949
# Epoch 48/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2084 - accuracy: 0.9143 - val_loss: 0.1793 - val_accuracy: 0.9235
# Epoch 49/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2073 - accuracy: 0.9130 - val_loss: 0.1731 - val_accuracy: 0.9360
# Epoch 50/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2145 - accuracy: 0.9139 - val_loss: 0.1736 - val_accuracy: 0.9364

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.1628 - accuracy: 0.9394
# Test Accuracy: 93.9377%
