# %% [markdown]
#  # Convolutional Neural Network Implementation

# %%
## Imports

import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd
import tensorflow as tf 
import os
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
## Data Load

CLASS = {'Cars':0, 'Drones': 1, 'People':2}

list_of_file = []   # filename/details
list_of_img = []    # x
list_of_classi = [] # y

for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if file.endswith('.csv'):
            tmp = root.strip().split('\\')
            if tmp[-2] in CLASS:
                list_of_classi.append(CLASS[tmp[-2]])
                list_of_file.append(os.path.join('\\'.join(tmp[-3:]),file))
                df = pd.read_csv(os.path.join(root,file), sep=',',header=None)
                list_of_img.append(df.values)

x = np.array(list_of_img)
y = np.array(list_of_classi)
d = np.array(list_of_file)
                
print(len(list_of_file), 'files loaded.')
# Out:
# 17485 files loaded.

# %% [markdown]
# # Example Person Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[16300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[16300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Drone Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[10300], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[10300]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Example Car Sample

# %%
fig = plt.figure()
ax = plt.axes()
img = ax.imshow(list_of_img[100], vmin=-140, vmax=-70, cmap='jet')
plt.title('Range-Doppler for {}'.format(list_of_file[100]))
plt.axis('tight')
plt.ylabel('Range Bin')
plt.xlabel('Doppler Bin')
plt.colorbar(img)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing the Data
from sklearn.model_selection import train_test_split

## Convert list_of_img to linear, and scale to 0 to 1
#x = np.power(10, x/10)
#x = x/np.max(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=31, shuffle=True)

# %% [markdown]
# # Defining the Utility Functions to Plot Accuracies and Losses

# %%
#Defining utility functions to plot Accuracies and Losses

def smooth_curve(points,factor = 0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)

  return smoothed_points

def plot_convergence():
  plt.figure(figsize=(10, 5))
  plt.subplot(1,2,1)
  plt.plot(smooth_curve(history.history['accuracy']), marker= 'o', label = 'Train Accuracy')
  plt.plot(smooth_curve(history.history['val_accuracy']), marker= 'o', label = 'Validation Accuracy')
  plt.title('Training and Validation Accuracy over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(smooth_curve(history.history['loss']),marker = 'o', label = 'Train Loss')
  plt.plot(smooth_curve(history.history['val_loss']),marker = 'o', label = 'Validation Loss')
  plt.title('Training and Validation Loss over Epochs')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)
  plt.legend()

  plt.tight_layout()
  plt.show()

def test_model_accuracy(model):
  test_loss,test_accuracy = model.evaluate(x_test, y_test)
  print(f"Test Accuracy: {test_accuracy * 100:.4f}%")
  plot_convergence()

# %% [markdown]
# # Reshaping

# %%
from tensorflow.keras.utils import to_categorical
x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)

x_train=np.reshape(x_train,[-1,11,61,1])
x_test=np.reshape(x_test,[-1,11,61,1])

y_train = (to_categorical(y_train, 3))
y_test = (to_categorical(y_test, 3))

# %% [markdown]
# # Convolutional Model Building
# ### Convolutional Layer (32)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Convolutional Layer (64)
# ### Average Pooling Layer (2,2)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)
# ### Dropout Layer (0.25)
# ### Dense Layer (64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, MaxPooling2D,Activation,AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
## Model Building

#Starting with a model
model = Sequential([
        #Single Convolutional Layer
        Conv2D(32, (3,3), activation = 'relu', input_shape = (11,61,1)),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

         #Second Convolutional Layer
        Conv2D(64, (3,3), activation = 'relu',),

        #Added Pooling Layer
        AveragePooling2D(pool_size=(2, 2)),

        Dropout(0.25),  # Dropout layer after pooling

        #Flattening the output to feed the dense layer
        Flatten(),
        
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        Dropout(0.25),  # Dropout layer after dense
        Dense(64, activation = 'relu'),
        

        #Output Layer with softmax activation for multi-class classification
        Dense(3, activation = 'softmax')
])

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 9, 59, 32)         320
#
#  average_pooling2d (AverageP  (None, 4, 29, 32)        0
#  ooling2D)
#
#  dropout (Dropout)           (None, 4, 29, 32)         0
#
#  conv2d_1 (Conv2D)           (None, 2, 27, 64)         18496
#
#  average_pooling2d_1 (Averag  (None, 1, 13, 64)        0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 1, 13, 64)         0
#
#  flatten (Flatten)           (None, 832)               0
#
#  dense (Dense)               (None, 64)                53312
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 80,643
# Trainable params: 80,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2,batch_size=64)
# Out:
# Epoch 1/50
# 175/175 [==============================] - 3s 13ms/step - loss: 1.3200 - accuracy: 0.3584 - val_loss: 1.0935 - val_accuracy: 0.3888
# Epoch 2/50
# 175/175 [==============================] - 2s 14ms/step - loss: 1.0932 - accuracy: 0.3795 - val_loss: 1.0887 - val_accuracy: 0.3888
# Epoch 3/50
# 175/175 [==============================] - 2s 13ms/step - loss: 1.0922 - accuracy: 0.3830 - val_loss: 1.0916 - val_accuracy: 0.3888
# Epoch 4/50
# 175/175 [==============================] - 2s 13ms/step - loss: 1.0875 - accuracy: 0.3856 - val_loss: 1.0901 - val_accuracy: 0.3888
# Epoch 5/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.9167 - accuracy: 0.5352 - val_loss: 0.4926 - val_accuracy: 0.8084
# Epoch 6/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.5307 - accuracy: 0.7746 - val_loss: 0.3663 - val_accuracy: 0.8538
# Epoch 7/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4309 - accuracy: 0.8198 - val_loss: 0.3201 - val_accuracy: 0.8581
# Epoch 8/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3787 - accuracy: 0.8471 - val_loss: 0.3180 - val_accuracy: 0.8667
# Epoch 9/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3643 - accuracy: 0.8473 - val_loss: 0.2518 - val_accuracy: 0.9056
# Epoch 10/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.3407 - accuracy: 0.8634 - val_loss: 0.2414 - val_accuracy: 0.9049
# Epoch 11/50
# 175/175 [==============================] - 3s 14ms/step - loss: 0.3187 - accuracy: 0.8696 - val_loss: 0.2239 - val_accuracy: 0.9142
# Epoch 12/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3027 - accuracy: 0.8761 - val_loss: 0.2104 - val_accuracy: 0.9207
# Epoch 13/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2970 - accuracy: 0.8747 - val_loss: 0.2165 - val_accuracy: 0.9157
# Epoch 14/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2802 - accuracy: 0.8849 - val_loss: 0.1999 - val_accuracy: 0.9221
# Epoch 15/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2768 - accuracy: 0.8875 - val_loss: 0.2275 - val_accuracy: 0.9042
# Epoch 16/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2782 - accuracy: 0.8844 - val_loss: 0.2039 - val_accuracy: 0.9185
# Epoch 17/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2612 - accuracy: 0.8910 - val_loss: 0.2062 - val_accuracy: 0.9199
# Epoch 18/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2595 - accuracy: 0.8948 - val_loss: 0.2154 - val_accuracy: 0.9117
# Epoch 19/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.2592 - accuracy: 0.8929 - val_loss: 0.1995 - val_accuracy: 0.9289
# Epoch 20/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2513 - accuracy: 0.8990 - val_loss: 0.2016 - val_accuracy: 0.9228
# Epoch 21/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2420 - accuracy: 0.9020 - val_loss: 0.1940 - val_accuracy: 0.9260
# Epoch 22/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2504 - accuracy: 0.8953 - val_loss: 0.2056 - val_accuracy: 0.9239
# Epoch 23/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2495 - accuracy: 0.8981 - val_loss: 0.1771 - val_accuracy: 0.9367
# Epoch 24/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2401 - accuracy: 0.9004 - val_loss: 0.1910 - val_accuracy: 0.9242
# Epoch 25/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2346 - accuracy: 0.9068 - val_loss: 0.1821 - val_accuracy: 0.9303
# Epoch 26/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2342 - accuracy: 0.9012 - val_loss: 0.1788 - val_accuracy: 0.9292
# Epoch 27/50
# 175/175 [==============================] - 2s 10ms/step - loss: 0.2281 - accuracy: 0.9049 - val_loss: 0.1764 - val_accuracy: 0.9339
# Epoch 28/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2306 - accuracy: 0.9064 - val_loss: 0.2152 - val_accuracy: 0.9139
# Epoch 29/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2380 - accuracy: 0.9043 - val_loss: 0.1688 - val_accuracy: 0.9357
# Epoch 30/50
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2247 - accuracy: 0.9080 - val_loss: 0.1716 - val_accuracy: 0.9317
# Epoch 31/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2127 - accuracy: 0.9146 - val_loss: 0.1588 - val_accuracy: 0.9371
# Epoch 32/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2175 - accuracy: 0.9147 - val_loss: 0.1756 - val_accuracy: 0.9346
# Epoch 33/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2254 - accuracy: 0.9070 - val_loss: 0.2015 - val_accuracy: 0.9185
# Epoch 34/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2215 - accuracy: 0.9096 - val_loss: 0.1685 - val_accuracy: 0.9350
# Epoch 35/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2145 - accuracy: 0.9162 - val_loss: 0.1659 - val_accuracy: 0.9364
# Epoch 36/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2135 - accuracy: 0.9123 - val_loss: 0.1782 - val_accuracy: 0.9339
# Epoch 37/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.2316 - accuracy: 0.9052 - val_loss: 0.1617 - val_accuracy: 0.9410
# Epoch 38/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.2074 - accuracy: 0.9171 - val_loss: 0.1593 - val_accuracy: 0.9371
# Epoch 39/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2034 - accuracy: 0.9164 - val_loss: 0.1703 - val_accuracy: 0.9396
# Epoch 40/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2030 - accuracy: 0.9177 - val_loss: 0.1613 - val_accuracy: 0.9400
# Epoch 41/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1978 - accuracy: 0.9181 - val_loss: 0.1801 - val_accuracy: 0.9260
# Epoch 42/50
# 175/175 [==============================] - 2s 12ms/step - loss: 0.1999 - accuracy: 0.9181 - val_loss: 0.1599 - val_accuracy: 0.9410
# Epoch 43/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.2043 - accuracy: 0.9183 - val_loss: 0.1629 - val_accuracy: 0.9407
# Epoch 44/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.2052 - accuracy: 0.9130 - val_loss: 0.1653 - val_accuracy: 0.9400
# Epoch 45/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.1985 - accuracy: 0.9203 - val_loss: 0.1560 - val_accuracy: 0.9425
# Epoch 46/50
# 175/175 [==============================] - 2s 14ms/step - loss: 0.1921 - accuracy: 0.9215 - val_loss: 0.1644 - val_accuracy: 0.9400
# Epoch 47/50
# 175/175 [==============================] - 3s 15ms/step - loss: 0.1938 - accuracy: 0.9210 - val_loss: 0.1645 - val_accuracy: 0.9378
# Epoch 48/50
# 175/175 [==============================] - 3s 17ms/step - loss: 0.1960 - accuracy: 0.9243 - val_loss: 0.1623 - val_accuracy: 0.9396
# Epoch 49/50
# 175/175 [==============================] - 2s 13ms/step - loss: 0.1963 - accuracy: 0.9220 - val_loss: 0.1560 - val_accuracy: 0.9389
# Epoch 50/50
# 175/175 [==============================] - 2s 11ms/step - loss: 0.1957 - accuracy: 0.9223 - val_loss: 0.1872 - val_accuracy: 0.9317

# %%
test_model_accuracy(model)
# Out:
# 110/110 [==============================] - 0s 3ms/step - loss: 0.1950 - accuracy: 0.9202
# Test Accuracy: 92.0217%

# %%
from tensorflow.keras.models import load_model

model.save('cnn_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnn_model\assets
# INFO:tensorflow:Assets written to: cnn_model\assets

# %%
model2 = load_model('cnn_model')

# %%
from sklearn.metrics import classification_report

from sklearn.metrics import classification_report

y_pred = model.predict(x_test)

# Convert y_test from one-hot encoded to label encoded
y_test_labels = np.argmax(y_test, axis=1)
y_pred = np.argmax(y_pred, axis=1)

# Now you can generate the classification report
print(classification_report(y_test_labels, y_pred))
# Out:
# 110/110 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      1178
#            1       0.84      0.92      0.88       999
#            2       0.99      0.97      0.98      1320
#
#     accuracy                           0.92      3497
#    macro avg       0.92      0.92      0.92      3497
# weighted avg       0.92      0.92      0.92      3497

# %%
labels = ['car', 'drone', 'people']

evaluation = model.evaluate(x_test, y_test)
print(f'Test Accuracy : {evaluation[1] * 100:.2f}%')
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9202
# Test Accuracy : 92.02%

# %%
cm = confusion_matrix(y_test_labels, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labels)

fig, ax = plt.subplots(figsize=(10, 10))
disp = disp.plot(xticks_rotation='vertical', ax=ax,cmap='spring')

plt.show()
